# %%
import pandas as pd
import numpy as np
import yfinance as yf
import FinanceDataReader as fdr
from datetime import datetime, timedelta
from discord import send_message

# 기술적 분석 함수
def calculate_macd(data, short_window=12, long_window=26, signal_window=9):
    data['EMA12'] = data['Close'].ewm(span=short_window, adjust=False).mean()
    data['EMA26'] = data['Close'].ewm(span=long_window, adjust=False).mean()
    data['MACD'] = data['EMA12'] - data['EMA26']
    data['MACD_Signal'] = data['MACD'].ewm(span=signal_window, adjust=False).mean()
    return data


def calculate_stochastic(data, k_window=14, d_window=3):
    low_min = data['Low'].rolling(window=k_window).min()
    high_max = data['High'].rolling(window=k_window).max()
    data['%K'] = 100 * ((data['Close'] - low_min) / (high_max - low_min))
    data['%D'] = data['%K'].rolling(window=d_window).mean()
    return data


def calculate_rsi(data, window=7):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    data['RSI'] = 100 - (100 / (1 + rs))
    return data


def calculate_bollinger_bands(data, window=10):
    data['Middle_BB'] = data['Close'].rolling(window=window).mean()
    data['Upper_BB'] = data['Middle_BB'] + (data['Close'].rolling(window=window).std() * 2)
    data['Lower_BB'] = data['Middle_BB'] - (data['Close'].rolling(window=window).std() * 2)
    return data


def calculate_moving_averages(data):
    data['MA_5'] = data['Close'].rolling(window=5).mean()
    data['MA_20'] = data['Close'].rolling(window=20).mean()
    return data


def calculate_volume_metrics(data):
    data['Volume_MA_20'] = data['Volume'].rolling(window=20).mean()
    return data


def find_signal(data):
    data = calculate_macd(data)
    data = calculate_stochastic(data)
    data = calculate_rsi(data)
    data = calculate_bollinger_bands(data)
    data = calculate_moving_averages(data)
    data = calculate_volume_metrics(data)

    buy_conditions = [
        #('MACD', data['MACD'] > data['MACD_Signal']),
        #('Stochastic', data['%K'] > data['%D']),
        ('RSI', data['RSI'] > 30),
        ('Bollinger Lower', data['Close'] > data['Lower_BB']),
        ('Moving Average', data['MA_5'] > data['MA_20']),
        ('Volume', data['Volume'] > data['Volume_MA_20'])
    ]

    sell_conditions = [
        ('MACD', data['MACD'] < data['MACD_Signal']),
        ('Stochastic', data['%K'] < data['%D']),
        ('RSI', data['RSI'] > 70),
        ('Bollinger Upper', data['Close'] > data['Upper_BB']),
        ('Volume', data['Volume'] > data['Volume_MA_20'])
    ]
    
    data['buy_signal'] = True
    for _, cond in buy_conditions:
        data['buy_signal'] &= cond

    data['sell_signal'] = True
    for _, cond in sell_conditions:
        data['sell_signal'] &= cond    

    num_buy_conditions = len(buy_conditions)
    num_sell_conditions = len(sell_conditions)
    
    data['buy_signal_rate'] = sum(cond for _, cond in buy_conditions) / num_buy_conditions * 100
    data['sell_signal_rate'] = sum(cond for _, cond in sell_conditions) / num_sell_conditions * 100

    #print(data['buy_signal_rate'])
    return data

# 실시간 펀더멘털 데이터 가져오기
def get_fundamentals(symbols):
    financials = []
    for symbol in symbols:
        stock = yf.Ticker(symbol)
        try:
            per = stock.info.get('forwardPE', np.nan)
            pbr = stock.info.get('priceToBook', np.nan)
            roe = stock.info.get('returnOnEquity', np.nan) * 100 if stock.info.get('returnOnEquity') else np.nan
            revenue_growth = stock.info.get('revenueGrowth', np.nan)
            eps_growth = stock.info.get('earningsGrowth', np.nan)
            div_yield = stock.info.get('dividendYield', np.nan) * 100 if stock.info.get('dividendYield') else 0
            roic = stock.info.get('returnOnAssets', np.nan) * 100 if stock.info.get('returnOnAssets') else np.nan
            
            if not np.isnan([per, pbr, roe, revenue_growth, eps_growth, div_yield, roic]).any():
                financials.append((symbol, per, pbr, roe, revenue_growth, eps_growth, div_yield, roic))
        except:
            #print("ABC")
            continue
    return financials

# 펀더멘털 분석 함수
def filter_stocks(financials, min_roic=5, min_eps_growth=0.05, min_revenue_growth=0.02, min_roe=1, max_per=100, max_pbr=30, min_div_yield=0):
    filtered_stocks = []
    for stock in financials:
        symbol, per, pbr, roe, revenue_growth, eps_growth, div_yield, roic = stock
        #print(symbol, per, pbr, roe)
        if per < max_per and pbr < max_pbr and roe > min_roe:
        #if revenue_growth > min_revenue_growth and eps_growth > min_eps_growth and per < max_per and pbr < max_pbr and roe > min_roe and div_yield > min_div_yield and roic > min_roic:
            filtered_stocks.append(symbol)
    return filtered_stocks

# 백테스트 함수
def backtest_with_stop_loss(symbol, start="2024-01-01", stop_loss=-5):
    end = (datetime.strptime(start, "%Y-%m-%d") + timedelta(days=365)).strftime("%Y-%m-%d")
    df = fdr.DataReader(symbol, start, end)
    df = df[['Close', 'Volume', 'High', 'Low']]
    df = find_signal(df)
    
    initial_cash = 1500
    cash = initial_cash
    position = 0
    buy_price = 0
    trade_log = []
    
    for i in range(len(df)):
        date = df.index[i].strftime("%Y-%m-%d")
        close_price = df['Close'].iloc[i]

        if df['buy_signal_rate'].iloc[i] > 70 and cash > 0:
            buy_amount = initial_cash * 0.2
            buy_quantity = buy_amount / close_price
            position += buy_quantity
            cash -= buy_amount
            buy_price = close_price
            trade_log.append(f"[{date}] 매수: 가격 {close_price:.2f}, 매수량 {buy_quantity:.4f}, 남은 현금 ${cash:.2f}")
        
        if position > 0 and ((close_price - buy_price) / buy_price) * 100 <= stop_loss:
            #sell_quantity = position * 0.2  # 보유 주식의 20% 매도
            sell_amount = position * close_price
            cash += sell_amount
            trade_log.append(f"[{date}] 손절 매도: 가격 {close_price:.2f}, 손실률: {((close_price - buy_price) / buy_price) * 100:.2f}%, 보유 현금 ${cash:.2f}")
            position = 0
            buy_price = 0
        
        elif df['sell_signal_rate'].iloc[i] > 70 and position > 0:
            sell_quantity = position * 0.2
            sell_amount = sell_quantity * close_price
            position -= sell_quantity
            cash += sell_amount
            trade_log.append(f"[{date}] 매도: 가격 {close_price:.2f}, 매도량 {sell_quantity:.4f}, 보유 현금 ${cash:.2f}")
    
    final_value = cash + (position * df['Close'].iloc[-1])
    total_return = (final_value - initial_cash) / initial_cash * 100

    df.dropna(inplace=True)
    today = datetime.today() - timedelta(days=1)
    if today.weekday() in [5, 6]:  # 토요일(5) 또는 일요일(6)이라면
        today -= timedelta(days=today.weekday() - 4)
    today_str = today.strftime("%Y-%m-%d")
    
    #print(today_str, df.index[-1].strftime("%Y-%m-%d"))
    if today_str == df.index[-1].strftime("%Y-%m-%d"):
        #today_signals = df.loc[today_str, ["buy_signal_growth", "sell_signal_growth", "buy_signal_bluechip", "sell_signal_bluechip"]]
        #if today_signals.any():
        #print(df.loc[today_str])
        signal = df.loc[today_str]

    return total_return, trade_log, signal

# 백테스트 실행
symbols = ['TSLA', 'PLTR', 'ACHR', 'O', 'AAPL']
filtered_symbols = symbols
#financials = get_fundamentals(symbols)
#filtered_symbols = filter_stocks(financials)
#print(filtered_symbols)
results = {}
signals = {}

for symbol in filtered_symbols:
    total_return, trades, signal = backtest_with_stop_loss(symbol, start="2025-01-01")
    results[symbol] = total_return
    signals[symbol] = signal
    print(f"\n📊 [{symbol}] 손절 적용 후 총 수익률: {total_return:.2f}%")
    for trade in trades[-5:]:
        print(trade)

sorted_results = sorted(results.items(), key=lambda x: x[1], reverse=True)
print("\n📈 필터링 후 수익률 TOP 종목:")
for symbol, return_rate in sorted_results:
    print(f"{symbol}: {return_rate:.2f}%")

best_symbol = sorted_results[0][0]
print(f"\n🚀 가장 높은 수익률을 기록한 종목: {best_symbol}")

send_message(signals)

#print(signals)
# Out:
# /Users/user/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 📊 [TSLA] 손절 적용 후 총 수익률: -9.03%
# [2025-02-10] 손절 매도: 가격 350.73, 손실률: -6.30%, 보유 현금 $1465.58
# [2025-02-13] 매수: 가격 355.94, 매수량 0.8428, 남은 현금 $1165.58
# [2025-02-21] 매수: 가격 337.80, 매수량 0.8881, 남은 현금 $865.58
# [2025-02-24] 매수: 가격 330.53, 매수량 0.9076, 남은 현금 $565.58
# [2025-02-25] 손절 매도: 가격 302.80, 손실률: -8.39%, 보유 현금 $1364.54
#
# 📊 [PLTR] 손절 적용 후 총 수익률: 1.33%
# [2025-01-31] 매수: 가격 82.49, 매수량 3.6368, 남은 현금 $900.00
# [2025-02-03] 매수: 가격 83.74, 매수량 3.5825, 남은 현금 $600.00
# [2025-02-04] 매수: 가격 103.83, 매수량 2.8893, 남은 현금 $300.00
# [2025-02-05] 매수: 가격 101.36, 매수량 2.9597, 남은 현금 $0.00
# [2025-02-24] 손절 매도: 가격 90.68, 손실률: -10.54%, 보유 현금 $1519.99
#
# 📊 [ACHR] 손절 적용 후 총 수익률: -13.88%
# [2025-02-11] 매수: 가격 9.29, 매수량 32.2928, 남은 현금 $300.00
# [2025-02-12] 매수: 가격 9.36, 매수량 32.0513, 남은 현금 $0.00
# [2025-02-24] 손절 매도: 가격 8.35, 손실률: -10.79%, 보유 현금 $1325.66
# [2025-02-28] 매수: 가격 8.88, 매수량 33.7838, 남은 현금 $1025.66
# [2025-03-03] 손절 매도: 가격 7.88, 손실률: -11.26%, 보유 현금 $1291.87
#
# 📊 [O] 손절 적용 후 총 수익률: 5.88%
# [2025-01-30] 매수: 가격 54.32, 매수량 5.5228, 남은 현금 $1200.00
# [2025-01-31] 매수: 가격 54.64, 매수량 5.4905, 남은 현금 $900.00
# [2025-02-03] 매수: 가격 54.49, 매수량 5.5056, 남은 현금 $600.00
# [2025-02-04] 매수: 가격 54.03, 매수량 5.5525, 남은 현금 $300.00
# [2025-02-06] 매수: 가격 54.29, 매수량 5.5259, 남은 현금 $0.00
#
# 📊 [AAPL] 손절 적용 후 총 수익률: 2.39%
# [2025-01-31] 매수: 가격 236.00, 매수량 1.2712, 남은 현금 $1200.00
# [2025-02-03] 매수: 가격 228.01, 매수량 1.3157, 남은 현금 $900.00
# [2025-02-04] 매수: 가격 232.80, 매수량 1.2887, 남은 현금 $600.00
# [2025-02-05] 매수: 가격 232.47, 매수량 1.2905, 남은 현금 $300.00
# [2025-02-06] 매수: 가격 233.22, 매수량 1.2863, 남은 현금 $0.00
#
# 📈 필터링 후 수익률 TOP 종목:
# O: 5.88%
# AAPL: 2.39%
# PLTR: 1.33%
# TSLA: -9.03%
# ACHR: -13.88%
#
# 🚀 가장 높은 수익률을 기록한 종목: O
# ✅ 메시지 전송 성공!
# ✅ 메시지 전송 성공!
# ✅ 메시지 전송 성공!
# ✅ 메시지 전송 성공!
# ✅ 메시지 전송 성공!

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import FinanceDataReader as fdr
from datetime import datetime, timedelta
from discord import send_message

# 기술적 분석 함수
def calculate_macd(data, short_window=12, long_window=26, signal_window=9):
    data['EMA12'] = data['Close'].ewm(span=short_window, adjust=False).mean()
    data['EMA26'] = data['Close'].ewm(span=long_window, adjust=False).mean()
    data['MACD'] = data['EMA12'] - data['EMA26']
    data['MACD_Signal'] = data['MACD'].ewm(span=signal_window, adjust=False).mean()
    return data


def calculate_stochastic(data, k_window=14, d_window=3):
    low_min = data['Low'].rolling(window=k_window).min()
    high_max = data['High'].rolling(window=k_window).max()
    data['%K'] = 100 * ((data['Close'] - low_min) / (high_max - low_min))
    data['%D'] = data['%K'].rolling(window=d_window).mean()
    return data


def calculate_rsi(data, window=7):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    data['RSI'] = 100 - (100 / (1 + rs))
    return data


def calculate_bollinger_bands(data, window=10):
    data['Middle_BB'] = data['Close'].rolling(window=window).mean()
    data['Upper_BB'] = data['Middle_BB'] + (data['Close'].rolling(window=window).std() * 2)
    data['Lower_BB'] = data['Middle_BB'] - (data['Close'].rolling(window=window).std() * 2)
    return data


def calculate_moving_averages(data):
    data['MA_5'] = data['Close'].rolling(window=5).mean()
    data['MA_20'] = data['Close'].rolling(window=20).mean()
    return data


def calculate_volume_metrics(data):
    data['Volume_MA_20'] = data['Volume'].rolling(window=20).mean()
    return data


def find_signal(data):
    data = calculate_macd(data)
    data = calculate_stochastic(data)
    data = calculate_rsi(data)
    data = calculate_bollinger_bands(data)
    data = calculate_moving_averages(data)
    data = calculate_volume_metrics(data)

    buy_conditions = [
        #('MACD', data['MACD'] > data['MACD_Signal']),
        #('Stochastic', data['%K'] > data['%D']),
        ('RSI', data['RSI'] > 30),
        ('Bollinger Lower', data['Close'] > data['Lower_BB']),
        ('Moving Average', data['MA_5'] > data['MA_20']),
        ('Volume', data['Volume'] > data['Volume_MA_20'])
    ]

    sell_conditions = [
        ('MACD', data['MACD'] < data['MACD_Signal']),
        ('Stochastic', data['%K'] < data['%D']),
        ('RSI', data['RSI'] > 70),
        ('Bollinger Upper', data['Close'] > data['Upper_BB']),
        ('Volume', data['Volume'] > data['Volume_MA_20'])
    ]
    
    data['buy_signal'] = True
    for _, cond in buy_conditions:
        data['buy_signal'] &= cond

    data['sell_signal'] = True
    for _, cond in sell_conditions:
        data['sell_signal'] &= cond    

    num_buy_conditions = len(buy_conditions)
    num_sell_conditions = len(sell_conditions)
    
    data['buy_signal_rate'] = sum(cond for _, cond in buy_conditions) / num_buy_conditions * 100
    data['sell_signal_rate'] = sum(cond for _, cond in sell_conditions) / num_sell_conditions * 100

    #print(data['buy_signal_rate'])
    return data

# 실시간 펀더멘털 데이터 가져오기
def get_fundamentals(symbols):
    financials = []
    for symbol in symbols:
        stock = yf.Ticker(symbol)
        try:
            per = stock.info.get('forwardPE', np.nan)
            pbr = stock.info.get('priceToBook', np.nan)
            roe = stock.info.get('returnOnEquity', np.nan) * 100 if stock.info.get('returnOnEquity') else np.nan
            revenue_growth = stock.info.get('revenueGrowth', np.nan)
            eps_growth = stock.info.get('earningsGrowth', np.nan)
            div_yield = stock.info.get('dividendYield', np.nan) * 100 if stock.info.get('dividendYield') else 0
            roic = stock.info.get('returnOnAssets', np.nan) * 100 if stock.info.get('returnOnAssets') else np.nan
            
            if not np.isnan([per, pbr, roe, revenue_growth, eps_growth, div_yield, roic]).any():
                financials.append((symbol, per, pbr, roe, revenue_growth, eps_growth, div_yield, roic))
        except:
            #print("ABC")
            continue
    return financials

# 펀더멘털 분석 함수
def filter_stocks(financials, min_roic=5, min_eps_growth=0.05, min_revenue_growth=0.02, min_roe=1, max_per=100, max_pbr=30, min_div_yield=0):
    filtered_stocks = []
    for stock in financials:
        symbol, per, pbr, roe, revenue_growth, eps_growth, div_yield, roic = stock
        #print(symbol, per, pbr, roe)
        if per < max_per and pbr < max_pbr and roe > min_roe:
        #if revenue_growth > min_revenue_growth and eps_growth > min_eps_growth and per < max_per and pbr < max_pbr and roe > min_roe and div_yield > min_div_yield and roic > min_roic:
            filtered_stocks.append(symbol)
    return filtered_stocks

# 백테스트 함수
def backtest_with_stop_loss(symbol, start="2024-01-01", stop_loss=-5):
    end = (datetime.strptime(start, "%Y-%m-%d") + timedelta(days=365)).strftime("%Y-%m-%d")
    df = fdr.DataReader(symbol, start, end)
    df = df[['Close', 'Volume', 'High', 'Low']]
    df = find_signal(df)
    
    initial_cash = 1500
    cash = initial_cash
    position = 0
    buy_price = 0
    trade_log = []
    
    for i in range(len(df)):
        date = df.index[i].strftime("%Y-%m-%d")
        close_price = df['Close'].iloc[i]

        if df['buy_signal_rate'].iloc[i] > 70 and cash > 0:
            buy_amount = initial_cash * 0.2
            buy_quantity = buy_amount / close_price
            position += buy_quantity
            cash -= buy_amount
            buy_price = close_price
            trade_log.append(f"[{date}] 매수: 가격 {close_price:.2f}, 매수량 {buy_quantity:.4f}, 남은 현금 ${cash:.2f}")
        
        if position > 0 and ((close_price - buy_price) / buy_price) * 100 <= stop_loss:
            #sell_quantity = position * 0.2  # 보유 주식의 20% 매도
            sell_amount = position * close_price
            cash += sell_amount
            trade_log.append(f"[{date}] 손절 매도: 가격 {close_price:.2f}, 손실률: {((close_price - buy_price) / buy_price) * 100:.2f}%, 보유 현금 ${cash:.2f}")
            position = 0
            buy_price = 0
        
        elif df['sell_signal_rate'].iloc[i] > 70 and position > 0:
            sell_quantity = position * 0.2
            sell_amount = sell_quantity * close_price
            position -= sell_quantity
            cash += sell_amount
            trade_log.append(f"[{date}] 매도: 가격 {close_price:.2f}, 매도량 {sell_quantity:.4f}, 보유 현금 ${cash:.2f}")
    
    final_value = cash + (position * df['Close'].iloc[-1])
    total_return = (final_value - initial_cash) / initial_cash * 100

    df.dropna(inplace=True)
    today = datetime.today() - timedelta(days=1)
    if today.weekday() in [5, 6]:  # 토요일(5) 또는 일요일(6)이라면
        today -= timedelta(days=today.weekday() - 4)
    today_str = today.strftime("%Y-%m-%d")
    
    #print(today_str, df.index[-1].strftime("%Y-%m-%d"))
    if today_str == df.index[-1].strftime("%Y-%m-%d"):
        #today_signals = df.loc[today_str, ["buy_signal_growth", "sell_signal_growth", "buy_signal_bluechip", "sell_signal_bluechip"]]
        #if today_signals.any():
        #print(df.loc[today_str])
        signal = df.loc[today_str]

    return total_return, trade_log, signal, df

# 백테스트 실행
symbols = ['TSLA', 'PLTR', 'ACHR', 'O', 'AAPL']
filtered_symbols = symbols
#financials = get_fundamentals(symbols)
#filtered_symbols = filter_stocks(financials)
#print(filtered_symbols)
results = {}
signals = {}
stock_df = {}

for symbol in filtered_symbols:
    total_return, trades, signal, df = backtest_with_stop_loss(symbol, start="2025-01-01")
    results[symbol] = total_return
    signals[symbol] = signal
    stock_df[symbol] = df
    print(f"\n📊 [{symbol}] 손절 적용 후 총 수익률: {total_return:.2f}%")
    for trade in trades[-5:]:
        print(trade)

sorted_results = sorted(results.items(), key=lambda x: x[1], reverse=True)
print("\n📈 필터링 후 수익률 TOP 종목:")
for symbol, return_rate in sorted_results:
    print(f"{symbol}: {return_rate:.2f}%")

best_symbol = sorted_results[0][0]
print(f"\n🚀 가장 높은 수익률을 기록한 종목: {best_symbol}")

#send_message(signals)

#print(signals)
# Out:
# 📊 [TSLA] 손절 적용 후 총 수익률: -9.03%
# [2025-02-10] 손절 매도: 가격 350.73, 손실률: -6.30%, 보유 현금 $1465.58
# [2025-02-13] 매수: 가격 355.94, 매수량 0.8428, 남은 현금 $1165.58
# [2025-02-21] 매수: 가격 337.80, 매수량 0.8881, 남은 현금 $865.58
# [2025-02-24] 매수: 가격 330.53, 매수량 0.9076, 남은 현금 $565.58
# [2025-02-25] 손절 매도: 가격 302.80, 손실률: -8.39%, 보유 현금 $1364.54
#
# 📊 [PLTR] 손절 적용 후 총 수익률: 1.33%
# [2025-01-31] 매수: 가격 82.49, 매수량 3.6368, 남은 현금 $900.00
# [2025-02-03] 매수: 가격 83.74, 매수량 3.5825, 남은 현금 $600.00
# [2025-02-04] 매수: 가격 103.83, 매수량 2.8893, 남은 현금 $300.00
# [2025-02-05] 매수: 가격 101.36, 매수량 2.9597, 남은 현금 $0.00
# [2025-02-24] 손절 매도: 가격 90.68, 손실률: -10.54%, 보유 현금 $1519.99
#
# 📊 [ACHR] 손절 적용 후 총 수익률: -13.88%
# [2025-02-11] 매수: 가격 9.29, 매수량 32.2928, 남은 현금 $300.00
# [2025-02-12] 매수: 가격 9.36, 매수량 32.0513, 남은 현금 $0.00
# [2025-02-24] 손절 매도: 가격 8.35, 손실률: -10.79%, 보유 현금 $1325.66
# [2025-02-28] 매수: 가격 8.88, 매수량 33.7838, 남은 현금 $1025.66
# [2025-03-03] 손절 매도: 가격 7.88, 손실률: -11.26%, 보유 현금 $1291.87
#
# 📊 [O] 손절 적용 후 총 수익률: 5.88%
# [2025-01-30] 매수: 가격 54.32, 매수량 5.5228, 남은 현금 $1200.00
# [2025-01-31] 매수: 가격 54.64, 매수량 5.4905, 남은 현금 $900.00
# [2025-02-03] 매수: 가격 54.49, 매수량 5.5056, 남은 현금 $600.00
# [2025-02-04] 매수: 가격 54.03, 매수량 5.5525, 남은 현금 $300.00
# [2025-02-06] 매수: 가격 54.29, 매수량 5.5259, 남은 현금 $0.00
#
# 📊 [AAPL] 손절 적용 후 총 수익률: 2.39%
# [2025-01-31] 매수: 가격 236.00, 매수량 1.2712, 남은 현금 $1200.00
# [2025-02-03] 매수: 가격 228.01, 매수량 1.3157, 남은 현금 $900.00
# [2025-02-04] 매수: 가격 232.80, 매수량 1.2887, 남은 현금 $600.00
# [2025-02-05] 매수: 가격 232.47, 매수량 1.2905, 남은 현금 $300.00
# [2025-02-06] 매수: 가격 233.22, 매수량 1.2863, 남은 현금 $0.00
#
# 📈 필터링 후 수익률 TOP 종목:
# O: 5.88%
# AAPL: 2.39%
# PLTR: 1.33%
# TSLA: -9.03%
# ACHR: -13.88%
#
# 🚀 가장 높은 수익률을 기록한 종목: O

# %%
import matplotlib.pyplot as plt

df = stock_df['O']

#print(df['buy_signal_rate'])

last_date = df.index.max()
cutoff_date = last_date - pd.DateOffset(days=30)
df = df[df.index >= cutoff_date]

# 4️⃣ 신호에 따라 가격 표시
#df["buy_signal_price"] = df["Close"].where(df["buy_signal"], None)
#df["sell_signal_price"] = df["Close"].where(df["sell_signal"], None)

# 5️⃣ 차트 그리기
fig, ax1 = plt.subplots(figsize=(12, 6))

# 🔵 Close 가격 선 그래프 (첫 번째 y축)
ax1.plot(df.index, df["Close"], marker="o", linestyle="-", color="blue", label="Close Price")
ax1.set_xlabel("Date")
ax1.set_ylabel("Price", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")

# 🟢 Buy Signal 선 그래프 (두 번째 y축)
ax2 = ax1.twinx()  # 두 번째 y축 생성
ax2.plot(df.index, df["buy_signal_rate"], marker="o", linestyle="-", color="green", label="Buy Signal")
ax2.set_ylabel("Buy Signal", color="green")
#ax2.tick_params(axis="y", labelcolor="green")

ax2.plot(df.index, df["sell_signal_rate"], marker="o", linestyle="-", color="red", label="Sell Signal")
ax2.set_ylabel("Signal", color="black")
ax2.tick_params(axis="y", labelcolor="black")

# 그래프 제목 및 스타일 설정
ax1.set_title("Stock Price with Buy & Sell Signals (Last 30 Days)")
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
fig.tight_layout()

# Jupyter 노트북에서 바로 보기
plt.show()

# 그래프 설정
plt.title("Stock Price with Buy & Sell Signals (Last 30 Days)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.legend()
plt.grid()

# 6️⃣ 차트 저장
image_path = "trade_signals.png"
plt.savefig(image_path)
plt.close()
# Out:
# /var/folders/v1/2rtgk4fj7_xbhwz35gj2392c0000gn/T/ipykernel_95872/627329904.py:48: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import requests

WEBHOOK_URL = "https://discord.com/api/webhooks/1345365931186196510/Gk9d1Nv-c03szRIdpqdRbvyHWVxu0JwI1QTsvUDTwWTciHmidBEMYos5Ua5JOxPZvOK4"  # 여기에 복사한 웹훅 URL 입력

with open(image_path, "rb") as file:
    files = {"file": image_path}
    response = requests.post(WEBHOOK_URL, files=files)

if response.status_code == 200:
    print("✅ 차트 전송 성공!")
else:
    print(f"❌ 전송 실패: {response.status_code}, {response.text}")
# Out:
# ✅ 차트 전송 성공!

# %%
result = []
for stock_name, df in stock_df.items():
    last_3_days = df.tail(3)
    close_2d = last_3_days['buy_signal_rate'].iloc[0]  # 2일 전
    close_1d = last_3_days['buy_signal_rate'].iloc[1]  # 1일 전
    close_today = last_3_days['buy_signal_rate'].iloc[2]  # 오늘
    
    # 종목과 해당 Close 값을 하나의 행으로 추가
    result.append([stock_name, close_2d, close_1d, close_today])

# 결과를 DataFrame으로 변환
final_df = pd.DataFrame(result, columns=['종목', 'Buy Signal 2일전', 'Buy Signal 1일전', 'Buy Signal 오늘'])

# Markdown 형식으로 테이블 생성
# 수동으로 Markdown 형식의 테이블 생성
markdown_table = "종목 | Close 2일전 | Close 1일전 | Close 오늘\n"
markdown_table += "---|-------------|-------------|------------\n"

for row in final_df.values:
    markdown_table += " | ".join(map(str, row)) + "\n"

print(markdown_table)
# Out:
# 종목 | Close 2일전 | Close 1일전 | Close 오늘
# ---|-------------|-------------|------------
# TSLA | 50.0 | 50.0 | 50.0
# PLTR | 25.0 | 50.0 | 25.0
# ACHR | 50.0 | 75.0 | 25.0
# O | 100.0 | 100.0 | 100.0
# AAPL | 25.0 | 100.0 | 100.0
